# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#this data analysis is to show and display various information from the dataset and organize them into charts and graphs with specific information to make it easier to read and get the vital parts inseatd of going through the whole dataste
# https://www.kaggle.com/datasets/gmadevs/atp-matches-dataset/code looked at all code for refrencing and get ideas
# https://www.kaggle.com/datasets/jordangoblet/atp-tour-20002016/code more ideas and tips used from the code provided

# %%
sns.set_theme()
plt.rcParams['font.family'] ='serif'
plt.rcParams['font.size']=18
plt.rcParams['xtick.labelsize']=16
plt.rcParams['ytick.labelsize']=16
plt.rcParams['axes.labelsize']=20
plt.rcParams['legend.fontsize']=18
plt.rcParams['legend.title_fontsize']=18
plt.rcParams['axes.titlesize'] =22

# %%
dfTennis=pd.read_csv('Mens_Tennis_Grand_Slam_Winner.csv')
#importing the dataset

# %%
dfTennis
#reading information from the dataset
# Out:
#      YEAR       TOURNAMENT           WINNER           RUNNER-UP  \
# 0    2022      French Open     Rafael Nadal         Casper Rudd
# 1    2022  Australian Open     Rafael Nadal     Daniil Medvedev
# 2    2021        U.S. Open  Daniil Medvedev      Novak Djokovic
# 3    2021        Wimbledon   Novak Djokovic   Matteo Berrettini
# 4    2021      French Open   Novak Djokovic  Stefanos Tsitsipas
# ..    ...              ...              ...                 ...
# 284  1951  Australian Open      Dick Savitt        Ken McGregor
# 285  1950        U.S. Open    Arthur Larsen        Herbert Flam
# 286  1950        Wimbledon       J.E. Patty       Frank Sedgman
# 287  1950      French Open      Budge Patty     Jaroslav Drobny
# 288  1950  Australian Open    Frank Sedgman        Ken McGregor
#
#     WINNER_NATIONALITY  WINNER_ATP_RANKING  RUNNER-UP_ATP_RANKING  \
# 0              Spanish                 5.0                    8.0
# 1              Spanish                 5.0                    2.0
# 2              Russian                 2.0                    1.0
# 3              Serbian                 1.0                    7.0
# 4              Serbian                 1.0                    4.0
# ..                 ...                 ...                    ...
# 284           American                 NaN                    NaN
# 285           American                 NaN                    NaN
# 286           American                 NaN                    NaN
# 287           American                 NaN                    NaN
# 288         Australian                 NaN                    NaN
#
#     WINNER_LEFT_OR_RIGHT_HANDED     TOURNAMENT_SURFACE  WINNER_PRIZE
# 0                          left                   Clay     1870000.0
# 1                          left  Plexicushion Prestige     4400000.0
# 2                         right    DecoTurf - outdoors     2500000.0
# 3                         right        Grass / Outdoor     1700000.0
# 4                         right                   Clay     1400000.0
# ..                          ...                    ...           ...
# 284                       right                  Grass           NaN
# 285                       right               outdoors           NaN
# 286                       right        Grass / Outdoor           NaN
# 287                       right                   Clay           NaN
# 288                       right                  Grass           NaN
#
# [289 rows x 10 columns]

# %%
dfTennis.dtypes
#using dtye i will know the datatyes stored in each column
# Out:
# YEAR                             int64
# TOURNAMENT                      object
# WINNER                          object
# RUNNER-UP                       object
# WINNER_NATIONALITY              object
# WINNER_ATP_RANKING             float64
# RUNNER-UP_ATP_RANKING          float64
# WINNER_LEFT_OR_RIGHT_HANDED     object
# TOURNAMENT_SURFACE              object
# WINNER_PRIZE                   float64
# dtype: object

# %%
dfTennis.describe()
#using the describe() i can look at the statistical data
# Out:
#               YEAR  WINNER_ATP_RANKING  RUNNER-UP_ATP_RANKING  WINNER_PRIZE
# count   289.000000            61.00000              61.000000  2.140000e+02
# mean   1985.602076             2.00000               3.540984  1.041317e+06
# std      20.911125             1.48324               2.520409  1.161834e+06
# min    1950.000000             1.00000               1.000000  2.000000e+03
# 25%    1968.000000             1.00000               2.000000  1.009688e+05
# 50%    1985.000000             1.00000               3.000000  5.925000e+05
# 75%    2004.000000             2.00000               5.000000  1.600000e+06
# max    2022.000000             9.00000              14.000000  4.538000e+06

# %%
dfTennis["WINNER_PRIZE"].mean()
#finding the mean of the prize
# Out:
# 1041317.238317757

# %%
dfTennis=dfTennis.drop(columns=['WINNER_ATP_RANKING', 'RUNNER-UP_ATP_RANKING'])

# %%
dfTennis
# Out:
#      YEAR       TOURNAMENT           WINNER           RUNNER-UP  \
# 0    2022      French Open     Rafael Nadal         Casper Rudd
# 1    2022  Australian Open     Rafael Nadal     Daniil Medvedev
# 2    2021        U.S. Open  Daniil Medvedev      Novak Djokovic
# 3    2021        Wimbledon   Novak Djokovic   Matteo Berrettini
# 4    2021      French Open   Novak Djokovic  Stefanos Tsitsipas
# ..    ...              ...              ...                 ...
# 284  1951  Australian Open      Dick Savitt        Ken McGregor
# 285  1950        U.S. Open    Arthur Larsen        Herbert Flam
# 286  1950        Wimbledon       J.E. Patty       Frank Sedgman
# 287  1950      French Open      Budge Patty     Jaroslav Drobny
# 288  1950  Australian Open    Frank Sedgman        Ken McGregor
#
#     WINNER_NATIONALITY WINNER_LEFT_OR_RIGHT_HANDED     TOURNAMENT_SURFACE  \
# 0              Spanish                        left                   Clay
# 1              Spanish                        left  Plexicushion Prestige
# 2              Russian                       right    DecoTurf - outdoors
# 3              Serbian                       right        Grass / Outdoor
# 4              Serbian                       right                   Clay
# ..                 ...                         ...                    ...
# 284           American                       right                  Grass
# 285           American                       right               outdoors
# 286           American                       right        Grass / Outdoor
# 287           American                       right                   Clay
# 288         Australian                       right                  Grass
#
#      WINNER_PRIZE
# 0       1870000.0
# 1       4400000.0
# 2       2500000.0
# 3       1700000.0
# 4       1400000.0
# ..            ...
# 284           NaN
# 285           NaN
# 286           NaN
# 287           NaN
# 288           NaN
#
# [289 rows x 8 columns]

# %%
for val_c in dfTennis.select_dtypes(exclude='number'):
    print()
    print(val_c)
    print(dfTennis[val_c].value_counts())
    print('-'*51)
# Out:
# TOURNAMENT
# French Open              73
# U.S. Open                72
# Australian Open          71
# Wimbledon                71
# Australian Open (Dec)     1
# Australian Open (Jan)     1
# Name: TOURNAMENT, dtype: int64
# ---------------------------------------------------
#
# WINNER
# Rafael Nadal        22
# Novak Djokovic      20
# Roger Federer       20
# Pete Sampras        14
# Roy Emerson         12
#                     ..
# Vitas Gerulaitis     1
# Roscoe Tanner        1
# Adriano Panatta      1
# Mark Edmondson       1
# Budge Patty          1
# Name: WINNER, Length: 82, dtype: int64
# ---------------------------------------------------
#
# RUNNER-UP
# Novak Djokovic        11
# Roger Federer         11
# Ivan Lendl            11
# Ken Rosewall           8
# Andy Murray            8
#                       ..
# MaliVai Washington     1
# Carlos Moya            1
# Sergi Bruguera         1
# Greg Rusedski          1
# Eric Sturgess          1
# Name: RUNNER-UP, Length: 131, dtype: int64
# ---------------------------------------------------
#
# WINNER_NATIONALITY
# American          67
# Australian        67
# Spanish           32
# Swedish           26
# Swiss             23
# Serbian           20
# Czechoslovakia     8
# German             7
# Argentine          6
# Russian            5
# Czech              4
# Italian            3
# Brazilian          3
# British            3
# Czechoslovak       3
# Croatian           2
# Austrian           2
# Romanian           2
# peruvian           2
# Dutch              1
# Ecuadorian         1
# French             1
# Mexican            1
# Name: WINNER_NATIONALITY, dtype: int64
# ---------------------------------------------------
#
# WINNER_LEFT_OR_RIGHT_HANDED
# right    224
# left      65
# Name: WINNER_LEFT_OR_RIGHT_HANDED, dtype: int64
# ---------------------------------------------------
#
# TOURNAMENT_SURFACE
# Clay                     73
# Grass / Outdoor          71
# DecoTurf - outdoors      44
# Grass                    38
# outdoors                 25
# Rebound Ace              20
# Plexicushion Prestige    15
# Clay - outdoors           3
# Name: TOURNAMENT_SURFACE, dtype: int64
# ---------------------------------------------------

# %%
for val_c in dfTennis.select_dtypes(exclude='object'):
    print()
    print(val_c)
    print(dfTennis[val_c].value_counts())
    print('--'*51)
# Out:
# YEAR
# 1977    5
# 1950    4
# 1978    4
# 1972    4
# 1973    4
#        ..
# 1990    4
# 1953    4
# 1986    3
# 2020    3
# 2022    2
# Name: YEAR, Length: 73, dtype: int64
# ------------------------------------------------------------------------------------------------------
#
# WINNER_PRIZE
# 1000000.0    6
# 100000.0     4
# 1200000.0    3
# 2000000.0    3
# 25000.0      3
#             ..
# 4538000.0    1
# 780000.0     1
# 525000.0     1
# 900000.0     1
# 14000.0      1
# Name: WINNER_PRIZE, Length: 162, dtype: int64
# ------------------------------------------------------------------------------------------------------

# %%
dfTennis["TOURNAMENT_SURFACE"].value_counts()
#display the different surfaces played on 
#instead of having 8 rows it will be better just to have 3 rows
# Out:
# Clay                     73
# Grass / Outdoor          71
# DecoTurf - outdoors      44
# Grass                    38
# outdoors                 25
# Rebound Ace              20
# Plexicushion Prestige    15
# Clay - outdoors           3
# Name: TOURNAMENT_SURFACE, dtype: int64

# %%
dfTennis["TOURNAMENT_SURFACE"].replace(to_replace=['DecoTurf - outdoors','outdoors','Rebound Ace','Plexicushion Prestige'],value='Hard Court',inplace=True)

# %%
dfTennis["TOURNAMENT_SURFACE"].replace(to_replace=['Grass / Outdoor','Clay - outdoors'],value=['Grass','Clay'],inplace=True)

# %%
dfTennis["TOURNAMENT_SURFACE"].value_counts()
#now the surface have been grouped into 3 rows
# Out:
# Grass         109
# Hard Court    104
# Clay           76
# Name: TOURNAMENT_SURFACE, dtype: int64

# %%
plt.figure(figsize=(8,9))
plt.pie(dfTennis["TOURNAMENT_SURFACE"].value_counts(),autopct='%.2f',frame=True,startangle=45,radius=2.5,colors=['green','steelblue','sandybrown'])
plt.legend(labels=['Grass','Hard Court','Clay'],loc=3)
plt.xticks(ticks=[])
plt.yticks(ticks=[])
plt.title("Number of matches on different courts")
#a ppie chhart to show the surfaces played on
# Out:
# Text(0.5, 1.0, 'Number of matches on different courts')

# %%
dfTennis['TOURNAMENT'].value_counts()
#count the number of tournoments
# Out:
# French Open              73
# U.S. Open                72
# Australian Open          71
# Wimbledon                71
# Australian Open (Dec)     1
# Australian Open (Jan)     1
# Name: TOURNAMENT, dtype: int64

# %%
dfTennis["TOURNAMENT"].replace(to_replace=['Australian Open (Dec)','Australian Open (Jan)'],value='Australian Open',inplace=True)
#combined the austrailian open into one group inetead of having 3

# %%
plt.figure(figsize=(15,8))
counts,edges,barrs=plt.hist(dfTennis['TOURNAMENT'],bins=7,align='mid',label='Number of matches per grand slam',color="green")
plt.title("number of matches for each grand slam")
plt.xlabel("grand slams")
plt.ylabel("recorded matches ")
plt.bar_label(barrs)
plt.grid(axis='x')
plt.plot()
#barchart for the tournoments
# Out:
# []

# %%
plt.figure(figsize=(19,10))
sns.lineplot(data=dfTennis,x='YEAR',y='WINNER_PRIZE',hue='TOURNAMENT',linewidth=3.6,palette=['sandybrown','lightseagreen','cornflowerblue','green'])
plt.title("grand slam prizes")
plt.xlabel("Years")
plt.ylabel(" Winner Prize($Million)")
plt.plot()
#graph represents the winnings in millions
# Out:
# []

# %%
dfTennis['WINNER_NATIONALITY'].replace(to_replace=['Czechoslovak','Czechoslovakia'],value='Czech',inplace=True)
# replace Czechoslovak with czech to make it neater

# %%
plt.figure(figsize=(36,15))
counts,edges,barrs=plt.hist(dfTennis['WINNER_NATIONALITY'],align='left',color="orange",bins=21)
plt.title("grand slam winner nationality")
plt.xlabel("Nationality")
plt.ylabel(" number of matches won ")
plt.bar_label(barrs)
plt.xticks(rotation=335)
plt.grid(axis='y')
plt.plot()
#display thee wins by counrty on a barchart
# Out:
# []

# %%
plt.figure(figsize=(27,24))
plt.grid(True)
sns.scatterplot(data=dfTennis,x='YEAR',y='WINNER_NATIONALITY',hue="TOURNAMENT",style='WINNER_LEFT_OR_RIGHT_HANDED',s=216,palette=['sandybrown','lightseagreen','cornflowerblue','green'])
plt.title("grand slam winner nationality")
plt.ylabel("Nationality")
plt.xlabel("Years ")
plt.plot()
#a chart t shows the winners and their playstyle for each tournoment 
#this cahrt shows the total amount of Left handed players who have won their tournament is not too large compared to the Right handed Players.
# Out:
# []

# %%
dfTennis.columns
dfTennis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, American to peruvian
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Australian Open  11 non-null     float64
#  1   French Open      15 non-null     float64
#  2   U.S. Open        15 non-null     float64
#  3   Wimbledon        12 non-null     float64
# dtypes: float64(4)
# memory usage: 840.0+ bytes

# %%
dfTennis.columns
# Out:
# Index(['Australian Open', 'French Open', 'U.S. Open', 'Wimbledon'], dtype='object', name='TOURNAMENT')

# %%
dfTennis=pd.read_csv('Mens_Tennis_Grand_Slam_Winner.csv')

# %%
dfTennis
# Out:
#      YEAR       TOURNAMENT           WINNER           RUNNER-UP  \
# 0    2022      French Open     Rafael Nadal         Casper Rudd
# 1    2022  Australian Open     Rafael Nadal     Daniil Medvedev
# 2    2021        U.S. Open  Daniil Medvedev      Novak Djokovic
# 3    2021        Wimbledon   Novak Djokovic   Matteo Berrettini
# 4    2021      French Open   Novak Djokovic  Stefanos Tsitsipas
# ..    ...              ...              ...                 ...
# 284  1951  Australian Open      Dick Savitt        Ken McGregor
# 285  1950        U.S. Open    Arthur Larsen        Herbert Flam
# 286  1950        Wimbledon       J.E. Patty       Frank Sedgman
# 287  1950      French Open      Budge Patty     Jaroslav Drobny
# 288  1950  Australian Open    Frank Sedgman        Ken McGregor
#
#     WINNER_NATIONALITY  WINNER_ATP_RANKING  RUNNER-UP_ATP_RANKING  \
# 0              Spanish                 5.0                    8.0
# 1              Spanish                 5.0                    2.0
# 2              Russian                 2.0                    1.0
# 3              Serbian                 1.0                    7.0
# 4              Serbian                 1.0                    4.0
# ..                 ...                 ...                    ...
# 284           American                 NaN                    NaN
# 285           American                 NaN                    NaN
# 286           American                 NaN                    NaN
# 287           American                 NaN                    NaN
# 288         Australian                 NaN                    NaN
#
#     WINNER_LEFT_OR_RIGHT_HANDED     TOURNAMENT_SURFACE  WINNER_PRIZE
# 0                          left                   Clay     1870000.0
# 1                          left  Plexicushion Prestige     4400000.0
# 2                         right    DecoTurf - outdoors     2500000.0
# 3                         right        Grass / Outdoor     1700000.0
# 4                         right                   Clay     1400000.0
# ..                          ...                    ...           ...
# 284                       right                  Grass           NaN
# 285                       right               outdoors           NaN
# 286                       right        Grass / Outdoor           NaN
# 287                       right                   Clay           NaN
# 288                       right                  Grass           NaN
#
# [289 rows x 10 columns]

# %%
dfTennis.columns
# Out:
# Index(['YEAR', 'TOURNAMENT', 'WINNER', 'RUNNER-UP', 'WINNER_NATIONALITY',
#        'WINNER_ATP_RANKING', 'RUNNER-UP_ATP_RANKING',
#        'WINNER_LEFT_OR_RIGHT_HANDED', 'TOURNAMENT_SURFACE', 'WINNER_PRIZE'],
#       dtype='object')

# %%
dfTennis_pivot=pd.pivot_table(data=dfTennis,columns=['TOURNAMENT'],index='WINNER_NATIONALITY',values='YEAR',aggfunc='count')
ax=dfTennis_pivot.plot(kind='bar',figsize=(32,25),width=0.9,color=['lightseagreen','sandybrown','cornflowerblue','green'])
for c in ax.containers:
    ax.bar_label(c, fmt='%.0f', label_type='edge')
plt.title("grand slam winner nationality")
plt.xlabel("Nationalities")
plt.ylabel("number of mathces won")
plt.xticks()
plt.yticks(ticks=[i for i in range(0,22,2)],labels= [i for i in range(0,22,2)])
plt.plot()
#created these two graphs to clearly dislay the winners, tournoments , playstyle and nationality and is much easier to read
# Out:
# []

# %%
dfTennis2_pivot=pd.pivot_table(data=dfTennis,columns=['TOURNAMENT'],index=['WINNER_NATIONALITY','WINNER_LEFT_OR_RIGHT_HANDED'],values='YEAR',aggfunc='count')
ax=dfTennis2_pivot.plot(kind='bar',figsize=(32,25),width=0.9,color=['lightseagreen','sandybrown','cornflowerblue','green'])
for c in ax.containers:
    ax.bar_label(c, fmt='%.0f', label_type='edge',padding=2)
plt.title("grand slam winners distribution")
plt.xlabel("Nationalities and Playstyle")
plt.ylabel("number of mathces won")
plt.xticks(rotation=90)
plt.yticks(ticks=[i for i in range(0,22,2)],labels= [i for i in range(0,22,2)])
plt.plot()
# Out:
# []

# %%
dfWinners=pd.pivot_table(data=dfTennis,index=['YEAR'],columns=['TOURNAMENT'],values='WINNER_PRIZE')
dfWinners
# Out:
# TOURNAMENT  Australian Open  Australian Open (Dec)  Australian Open (Jan)  \
# YEAR
# 1968                    NaN                    NaN                    NaN
# 1969                    NaN                    NaN                    NaN
# 1970                    NaN                    NaN                    NaN
# 1971                 9000.0                    NaN                    NaN
# 1972                 2000.0                    NaN                    NaN
# 1973                 6750.0                    NaN                    NaN
# 1974                 6500.0                    NaN                    NaN
# 1975                 9234.0                    NaN                    NaN
# 1976                 8156.0                    NaN                    NaN
# 1977                    NaN                41000.0                28000.0
# 1978                50015.0                    NaN                    NaN
# 1979                50015.0                    NaN                    NaN
# 1980                64000.0                    NaN                    NaN
# 1981                72000.0                    NaN                    NaN
# 1982                77500.0                    NaN                    NaN
# 1983               100000.0                    NaN                    NaN
# 1984               100000.0                    NaN                    NaN
# 1985               100000.0                    NaN                    NaN
# 1986                    NaN                    NaN                    NaN
# 1987               103875.0                    NaN                    NaN
# 1988               105000.0                    NaN                    NaN
# 1989               140000.0                    NaN                    NaN
# 1990               266667.0                    NaN                    NaN
# 1991               320000.0                    NaN                    NaN
# 1992               360000.0                    NaN                    NaN
# 1993               410000.0                    NaN                    NaN
# 1994               460000.0                    NaN                    NaN
# 1995               480000.0                    NaN                    NaN
# 1996               562000.0                    NaN                    NaN
# 1997               585000.0                    NaN                    NaN
# 1998               615000.0                    NaN                    NaN
# 1999               722000.0                    NaN                    NaN
# 2000               755000.0                    NaN                    NaN
# 2001               830500.0                    NaN                    NaN
# 2002              1000000.0                    NaN                    NaN
# 2003              1127850.0                    NaN                    NaN
# 2004              1200000.0                    NaN                    NaN
# 2005              1206620.0                    NaN                    NaN
# 2006              1220000.0                    NaN                    NaN
# 2007              1281000.0                    NaN                    NaN
# 2008              1370000.0                    NaN                    NaN
# 2009              2000000.0                    NaN                    NaN
# 2010              2100000.0                    NaN                    NaN
# 2011              2200000.0                    NaN                    NaN
# 2012              2300000.0                    NaN                    NaN
# 2013              2430000.0                    NaN                    NaN
# 2014              2650000.0                    NaN                    NaN
# 2015              3100000.0                    NaN                    NaN
# 2016              3400000.0                    NaN                    NaN
# 2017              3700000.0                    NaN                    NaN
# 2018              4000000.0                    NaN                    NaN
# 2019              4100000.0                    NaN                    NaN
# 2020              4120000.0                    NaN                    NaN
# 2021              2875000.0                    NaN                    NaN
# 2022              4400000.0                    NaN                    NaN
#
# TOURNAMENT  French Open  U.S. Open  Wimbledon
# YEAR
# 1968            15000.0    14000.0     2000.0
# 1969            35000.0    16000.0     3000.0
# 1970            56000.0    20000.0     3000.0
# 1971            48000.0    15000.0     3750.0
# 1972            48000.0    25000.0     5000.0
# 1973            70000.0    25000.0     5000.0
# 1974           120000.0    22500.0    10000.0
# 1975           120000.0    25000.0    10000.0
# 1976           130000.0    30000.0    12500.0
# 1977           190000.0    33000.0    15000.0
# 1978           210000.0    38000.0    19000.0
# 1979           208000.0    39000.0    20000.0
# 1980           221000.0    46000.0    20000.0
# 1981           250000.0    66000.0    21600.0
# 1982           400000.0    90000.0    41677.0
# 1983           500000.0   120000.0    66600.0
# 1984          1058600.0   160000.0   100000.0
# 1985          1338200.0   187500.0   130000.0
# 1986          1397250.0   210000.0   140000.0
# 1987          1303800.0   250000.0   155000.0
# 1988          1500240.0   275000.0   165000.0
# 1989          1791390.0   300000.0   190000.0
# 1990          2226100.0   350000.0   230000.0
# 1991          2448000.0   400000.0   240000.0
# 1992          2680000.0   500000.0   265000.0
# 1993          2680000.0   535000.0   305000.0
# 1994          3160000.0   550000.0   345000.0
# 1995          3320000.0   575000.0   365000.0
# 1996          3452000.0   600000.0   392500.0
# 1997          3668000.0   650000.0   415000.0
# 1998          3852000.0   700000.0   435000.0
# 1999          4040000.0   750000.0   455000.0
# 2000          4240000.0   800000.0   477500.0
# 2001          4538000.0   850000.0   500000.0
# 2002           780000.0   900000.0   525000.0
# 2003           840000.0  1000000.0   575000.0
# 2004           860000.0  1000000.0   602500.0
# 2005           880000.0  1100000.0   630000.0
# 2006           940000.0  1200000.0   655000.0
# 2007          1000000.0  1400000.0   700000.0
# 2008          1000000.0  1500000.0   750000.0
# 2009          1060000.0  1600000.0   850000.0
# 2010          1120000.0  1700000.0  1000000.0
# 2011          1200000.0  1800000.0  1100000.0
# 2012          1250000.0  1900000.0  1150000.0
# 2013          1500000.0  2600000.0  1600000.0
# 2014          1650000.0  3000000.0  1760000.0
# 2015          1800000.0  3300000.0  1880000.0
# 2016          2000000.0  3500000.0  2000000.0
# 2017          2100000.0  3700000.0  2200000.0
# 2018          2200000.0  3800000.0  2250000.0
# 2019          2300000.0  3850000.0  2350000.0
# 2020          1600000.0  2500000.0        NaN
# 2021          1400000.0  2500000.0  1700000.0
# 2022          1870000.0        NaN        NaN

# %%
dfWinners.plot(kind='line',subplots=True,figsize=(24,20),layout=(4,4),xlabel='Years',ylabel='Prize money',linewidth=5.4,colormap='Dark2')
plt.suptitle("Separating all Tournament Prizes")
# charts displaying the money prizes
# Out:
# Text(0.5, 0.98, 'Separating all Tournament Prizes')

# %%
dfTennis.columns
# Out:
# Index(['YEAR', 'TOURNAMENT', 'WINNER', 'RUNNER-UP', 'WINNER_NATIONALITY',
#        'WINNER_ATP_RANKING', 'RUNNER-UP_ATP_RANKING',
#        'WINNER_LEFT_OR_RIGHT_HANDED', 'TOURNAMENT_SURFACE', 'WINNER_PRIZE'],
#       dtype='object')

# %%
dfWinners=pd.DataFrame([dfTennis['WINNER'].unique(),dfTennis['WINNER'].value_counts()],index=['WINNER','Number of Wins']).transpose()
dfWinners
#lisitng the winners
# Out:
#              WINNER Number of Wins
# 0      Rafael Nadal             22
# 1   Daniil Medvedev             20
# 2    Novak Djokovic             20
# 3     Dominic Thiem             14
# 4     Roger Federer             12
# ..              ...            ...
# 77        R. Savitt              1
# 78      Dick Savitt              1
# 79    Arthur Larsen              1
# 80       J.E. Patty              1
# 81      Budge Patty              1
#
# [82 rows x 2 columns]

# %%
top_5=dfWinners.iloc[:6]
top_5
# getting the top 5 and top 10 winners only
# Out:
#             WINNER Number of Wins
# 0     Rafael Nadal             22
# 1  Daniil Medvedev             20
# 2   Novak Djokovic             20
# 3    Dominic Thiem             14
# 4    Roger Federer             12
# 5    Stan Wawrinka             11

# %%
top_10=dfWinners.iloc[:11]
top_10
# Out:
#                    WINNER Number of Wins
# 0            Rafael Nadal             22
# 1         Daniil Medvedev             20
# 2          Novak Djokovic             20
# 3           Dominic Thiem             14
# 4           Roger Federer             12
# 5           Stan Wawrinka             11
# 6             Andy Murray             11
# 7             Marin Cilic              8
# 8   Juan Martin del Potro              8
# 9             Marat Safin              8
# 10          Gaston Gaudio              8

# %%
plt.figure(figsize=(36,27))
sns.barplot(x=top_5['WINNER'],y=top_5['Number of Wins'])
plt.xticks(rotation=90)
plt.yticks(ticks=[i for i in range(0,22,2)],labels= [i for i in range(0,22,2)])
plt.plot()
#barchart displaying the top 5 and top 10
# Out:
# []

# %%
plt.figure(figsize=(36,27))
sns.barplot(x=top_10['WINNER'],y=top_10['Number of Wins'])
plt.xticks(rotation=90)
plt.yticks(ticks=[i for i in range(0,22,2)],labels= [i for i in range(0,22,2)])
plt.plot()
# Out:
# []
